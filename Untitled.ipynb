# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
x = np.linspace(0, 1, 10000)
y = np.exp(-x/0.0016)
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">
